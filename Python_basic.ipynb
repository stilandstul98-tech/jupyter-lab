# %%
print("Hello world")
# Out:
# Hello world

# %%
# створюэмо переменные
age = 25
name = "Alex"
salary = 50000.00
is_student = True

# %%
name
# Out:
# 'Alex'

# %%
age
# Out:
# 25

# %%
print(f"Меня зовут {name}, мены {age} лет")
print (f"My salary: {salary} grn")
# Out:
# Меня зовут Alex, мены 25 лет
# My salary: 50000.0 grn
